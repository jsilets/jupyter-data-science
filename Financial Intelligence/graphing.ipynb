# %%
import plotly.express as px
import yfinance as yf
data = yf.download("AAPL, TSLA, AMZN, FB", period='ytd', group_by = 'ticker')
data = data.round(2)

data['TSLA'].iloc[-90:].describe().astype(int)
# Out:
# [*********************100%***********************]  4 of 4 completed
#        Open  High  Low  Close  Adj Close     Volume
# count    90    90   90     90         90         90
# mean    431   442  419    432        432   57981623
# std      76    78   74     77         77   28427748
# min     279   284  273    274        274   17357700
# 25%     403   412  386    405        405   34379700
# 50%     423   433  414    423        423   49432950
# 75%     448   458  436    447        447   79552050
# max     653   654  618    649        649  118465000

# %%
data['TSLA']['Adj Close'].plot(figsize = (15,8))
plt.show()

# %%
data['TSLA']['Day_Perc_Change'] = data['TSLA']['Adj Close'].pct_change()*100
data.head()
# Out:
# <ipython-input-74-ea6146f2bec6>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 FB                                                 AMZN  \
#               Open    High     Low   Close Adj Close    Volume     Open
# Date
# 2020-01-02  206.75  209.79  206.27  209.78    209.78  12077100  1875.00
# 2020-01-03  207.21  210.40  206.95  208.67    208.67  11188400  1864.50
# 2020-01-06  206.70  212.78  206.52  212.60    212.60  17058900  1860.00
# 2020-01-07  212.82  214.58  211.75  213.06    213.06  14912400  1904.50
# 2020-01-08  213.00  216.24  212.61  215.22    215.22  13475000  1898.04
#
#                                        ...   TSLA                              \
# ...
